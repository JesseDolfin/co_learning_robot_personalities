# %% [markdown]
# # RL Test
# ## 1. Import

# %%
import os
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# ## 2. Load Env

# %%
env_name = 'CartPole-v1'
render_mode = None
env = gym.make(env_name,render_mode=render_mode) # Loads gymnasiums cart pole environment, render mode:("human","rgb_array","asci")

# %%
episodes =5
for episode in range(1,episodes+1):
    state = env.reset()
    terminated = False
    score = 0
    
    while not terminated:
        if render_mode:
            env.render()
        action = env.action_space.sample()
        observation, reward, terminated, truncated, info = env.step(action) # 'terminated' and 'truncated' instead of 'done'
        score += reward
    print('Episode:{} Score:{}'.format(episode,score))
env.close()
# Out:
# Episode:1 Score:12.0
# Episode:2 Score:17.0
# Episode:3 Score:13.0
# Episode:4 Score:11.0
# Episode:5 Score:47.0

# %% [markdown]
# ### 2.1 Understand Env

# %% [markdown]
# Observation Space:
#
#     | Num | Observation           | Min                 | Max               |
#     |-----|-----------------------|---------------------|-------------------|
#     | 0   | Cart Position         | -4.8                | 4.8               |
#     | 1   | Cart Velocity         | -Inf                | Inf               |
#     | 2   | Pole Angle            | ~ -0.418 rad (-24°) | ~ 0.418 rad (24°) |
#     | 3   | Pole Angular Velocity | -Inf                | Inf               |
#
# Action Space:
#
#     | Num | Action                 |
#     |-----|------------------------|
#     | 0   | Push cart to the left  |
#     | 1   | Push cart to the right |

# %%
print(observation)
# Out:
# [ 0.05585453 -0.20431228  0.21620396  1.0914639 ]

# %% [markdown]
# ## 3. Train Model

# %%
log_path = os.path.join('Training','Logs')

# %%
env = gym.make(env_name,render_mode=render_mode)
env = DummyVecEnv([lambda: env])
model = PPO('MlpPolicy',env,verbose=1,tensorboard_log=log_path) # MlpPolicy: Multi layer perceptron Policy
# Out:
# Using cuda device

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to Training/Logs/PPO_4
# -----------------------------
# | time/              |      |
# |    fps             | 834  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 693         |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008619828 |
# |    clip_fraction        | 0.0983      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | 0.00102     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.86        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.015      |
# |    value_loss           | 50.1        |
# -----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 model.learn(total_timesteps=20000)
#
# File ~/anaconda3/envs/RLTest/lib/python3.11/site-packages/stable_baselines3/ppo/ppo.py:315, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     306 def learn(
#     307     self: SelfPPO,
#     308     total_timesteps: int,
#    (...)
#     313     progress_bar: bool = False,
#     314 ) -> SelfPPO:
# --> 315     return super().learn(
#     316         total_timesteps=total_timesteps,
#     317         callback=callback,
#     318         log_interval=log_interval,
#     319         tb_log_name=tb_log_name,
#     320         reset_num_timesteps=reset_num_timesteps,
#     321         progress_bar=progress_bar,
#     322     )
#
# File ~/anaconda3/envs/RLTest/lib/python3.11/site-packages/stable_baselines3/common/on_policy_algorithm.py:299, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     296         self.logger.record("time/total_timesteps", self.num_timesteps, exclude="tensorboard")
#     297         self.logger.dump(step=self.num_timesteps)
# --> 299     self.train()
#     301 callback.on_training_end()
#     303 return self
#
# File ~/anaconda3/envs/RLTest/lib/python3.11/site-packages/stable_baselines3/ppo/ppo.py:217, in PPO.train(self)
#     214 if self.use_sde:
#     215     self.policy.reset_noise(self.batch_size)
# --> 217 values, log_prob, entropy = self.policy.evaluate_actions(rollout_data.observations, actions)
#     218 values = values.flatten()
#     219 # Normalize advantage
#
# File ~/anaconda3/envs/RLTest/lib/python3.11/site-packages/stable_baselines3/common/policies.py:730, in ActorCriticPolicy.evaluate_actions(self, obs, actions)
#     728 features = self.extract_features(obs)
#     729 if self.share_features_extractor:
# --> 730     latent_pi, latent_vf = self.mlp_extractor(features)
#     731 else:
#     732     pi_features, vf_features = features
#
# File ~/anaconda3/envs/RLTest/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/RLTest/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/anaconda3/envs/RLTest/lib/python3.11/site-packages/stable_baselines3/common/torch_layers.py:222, in MlpExtractor.forward(self, features)
#     217 def forward(self, features: th.Tensor) -> Tuple[th.Tensor, th.Tensor]:
#     218     """
#     219     :return: latent_policy, latent_value of the specified network.
#     220         If all layers are shared, then ``latent_policy == latent_value``
#     221     """
# --> 222     return self.forward_actor(features), self.forward_critic(features)
#
# File ~/anaconda3/envs/RLTest/lib/python3.11/site-packages/stable_baselines3/common/torch_layers.py:225, in MlpExtractor.forward_actor(self, features)
#     224 def forward_actor(self, features: th.Tensor) -> th.Tensor:
# --> 225     return self.policy_net(features)
#
# File ~/anaconda3/envs/RLTest/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/RLTest/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/anaconda3/envs/RLTest/lib/python3.11/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~/anaconda3/envs/RLTest/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/RLTest/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/anaconda3/envs/RLTest/lib/python3.11/site-packages/torch/nn/modules/linear.py:116, in Linear.forward(self, input)
#     115 def forward(self, input: Tensor) -> Tensor:
# --> 116     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %% [markdown]
# ## 4. Save and Reload Model

# %%
PPO_Path=os.path.join('Training','Saved_Models','PPO_Model_Cartpole')

# %%
model.save(PPO_Path)

# %%
del model

# %%
model = PPO.load(PPO_Path,env=env)

# %% [markdown]
# ## 5. Evaluation

# %%
evaluate_policy(model,env,n_eval_episodes=10,render=True if render_mode else False)
# Out:
# (500.0, 0.0)

# %%
env.close()

# %% [markdown]
# ### 5.1 Test Model

# %%
episodes =5
for episode in range(1,episodes+1):
    obs = env.reset()
    done = False
    score = 0
    
    while not done:
        if render_mode:
            env.render()
        action,_ = model.predict(obs) # outputs (action,state)
        obs, reward, done, info = env.step(action) # Because of the wrapper back to 'done' instead of terminated and truncated
        score += reward
    print('Episode:{} Score:{}'.format(episode,score))
env.close()
# Out:
# Episode:1 Score:[422.]
# Episode:2 Score:[500.]
# Episode:3 Score:[278.]
# Episode:4 Score:[444.]
# Episode:5 Score:[200.]

# %% [markdown]
# ### 5.2 View Logs in Tensorboard

# %%
training_log_path = os.path.join(log_path,'PPO_3')

# %%
#!tensorboard --logdir={training_log_path}

# %% [markdown]
# #### Core metrics to look at:
# 1. Average Reward
# 2. Average Episode Length
#
# #### Training strategies:
# 1. Train for longer
# 2. Hyperparameter Tuning

# %% [markdown]
# ## 6. Add Callback to Training

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold

# %%
save_path = os.path.join('Training','Saved_Models')

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=500,verbose=1)
eval_callback = EvalCallback(env,
                             callback_on_new_best=stop_callback,
                             eval_freq=4000,
                             best_model_save_path=save_path,
                             verbose=1)

# %%
model = PPO('MlpPolicy',env,verbose=1,tensorboard_log=log_path)
# Out:
# Using cuda device

# %%
model.learn(total_timesteps=60000,callback=eval_callback)
# Out:
# Logging to Training/Logs/PPO_4
# -----------------------------
# | time/              |      |
# |    fps             | 732  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 651         |
# |    iterations           | 2           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008851534 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | -0.0117     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.1        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0167     |
# |    value_loss           | 57          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 621         |
# |    iterations           | 3           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009371214 |
# |    clip_fraction        | 0.0712      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.662      |
# |    explained_variance   | 0.0955      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.4        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0195     |
# |    value_loss           | 37          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 601         |
# |    iterations           | 4           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008678351 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.625      |
# |    explained_variance   | 0.276       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.5        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0232     |
# |    value_loss           | 49.8        |
# -----------------------------------------
# /home/jesse/anaconda3/envs/RLTest/lib/python3.11/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=10000, episode_reward=256.60 +/- 126.15
# Episode length: 256.60 +/- 126.15
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 257          |
# |    mean_reward          | 257          |
# | time/                   |              |
# |    total_timesteps      | 10000        |
# | train/                  |              |
# |    approx_kl            | 0.0076232445 |
# |    clip_fraction        | 0.0519       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.61        |
# |    explained_variance   | 0.23         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.4         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0128      |
# |    value_loss           | 63.3         |
# ------------------------------------------
# New best mean reward!
# ------------------------------
# | time/              |       |
# |    fps             | 561   |
# |    iterations      | 5     |
# |    time_elapsed    | 18    |
# |    total_timesteps | 10240 |
# ------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 562        |
# |    iterations           | 6          |
# |    time_elapsed         | 21         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.00848091 |
# |    clip_fraction        | 0.0801     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.601     |
# |    explained_variance   | 0.495      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 10.9       |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0146    |
# |    value_loss           | 57.3       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 553         |
# |    iterations           | 7           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.011537196 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.595      |
# |    explained_variance   | 0.742       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.3        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0141     |
# |    value_loss           | 42.7        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 548          |
# |    iterations           | 8            |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0038420553 |
# |    clip_fraction        | 0.0312       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.589       |
# |    explained_variance   | 0.464        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 37.9         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00688     |
# |    value_loss           | 67.6         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 551         |
# |    iterations           | 9           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.009137789 |
# |    clip_fraction        | 0.0954      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.58       |
# |    explained_variance   | 0.639       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.1        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0133     |
# |    value_loss           | 54.2        |
# -----------------------------------------
# Eval num_timesteps=20000, episode_reward=500.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 500         |
# |    mean_reward          | 500         |
# | time/                   |             |
# |    total_timesteps      | 20000       |
# | train/                  |             |
# |    approx_kl            | 0.005998535 |
# |    clip_fraction        | 0.0555      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.576      |
# |    explained_variance   | 0.742       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.4        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00853    |
# |    value_loss           | 42.8        |
# -----------------------------------------
# New best mean reward!
# Stopping training because the mean reward 500.00  is above the threshold 500

# %% [markdown]
# ## 7. Change Policy

# %%
net_arch = dict(pi=[128,128,128,128],vf=[128,128,128,128])

# %%
model = PPO('MlpPolicy',env,verbose=1,tensorboard_log=log_path,policy_kwargs={'net_arch':net_arch})
# Out:
# Using cuda device

# %%
model.learn(total_timesteps=60000,callback=eval_callback)
# Out:
# Logging to Training/Logs/PPO_6
# -----------------------------
# | time/              |      |
# |    fps             | 779  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# /home/jesse/anaconda3/envs/RLTest/lib/python3.11/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=4000, episode_reward=307.80 +/- 173.23
# Episode length: 307.80 +/- 173.23
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 308          |
# |    mean_reward          | 308          |
# | time/                   |              |
# |    total_timesteps      | 4000         |
# | train/                  |              |
# |    approx_kl            | 0.0141510675 |
# |    clip_fraction        | 0.219        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.681       |
# |    explained_variance   | 0.00159      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.34         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0258      |
# |    value_loss           | 17.9         |
# ------------------------------------------
# New best mean reward!
# -----------------------------
# | time/              |      |
# |    fps             | 553  |
# |    iterations      | 2    |
# |    time_elapsed    | 7    |
# |    total_timesteps | 4096 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 555         |
# |    iterations           | 3           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.017102418 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.643      |
# |    explained_variance   | 0.433       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.55        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0338     |
# |    value_loss           | 26.9        |
# -----------------------------------------
# Eval num_timesteps=8000, episode_reward=336.60 +/- 99.27
# Episode length: 336.60 +/- 99.27
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 337        |
# |    mean_reward          | 337        |
# | time/                   |            |
# |    total_timesteps      | 8000       |
# | train/                  |            |
# |    approx_kl            | 0.01188527 |
# |    clip_fraction        | 0.162      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.604     |
# |    explained_variance   | 0.37       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 17.7       |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.029     |
# |    value_loss           | 41.8       |
# ----------------------------------------
# New best mean reward!
# -----------------------------
# | time/              |      |
# |    fps             | 512  |
# |    iterations      | 4    |
# |    time_elapsed    | 15   |
# |    total_timesteps | 8192 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 502         |
# |    iterations           | 5           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010184065 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.575      |
# |    explained_variance   | 0.614       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.7        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0222     |
# |    value_loss           | 40.5        |
# -----------------------------------------
# Eval num_timesteps=12000, episode_reward=304.60 +/- 28.77
# Episode length: 304.60 +/- 28.77
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 305         |
# |    mean_reward          | 305         |
# | time/                   |             |
# |    total_timesteps      | 12000       |
# | train/                  |             |
# |    approx_kl            | 0.012677131 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.56       |
# |    explained_variance   | 0.71        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.9         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0181     |
# |    value_loss           | 38.1        |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 481   |
# |    iterations      | 6     |
# |    time_elapsed    | 25    |
# |    total_timesteps | 12288 |
# ------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 478        |
# |    iterations           | 7          |
# |    time_elapsed         | 29         |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.01089566 |
# |    clip_fraction        | 0.138      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.55      |
# |    explained_variance   | 0.821      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 10.8       |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0149    |
# |    value_loss           | 18.6       |
# ----------------------------------------
# Eval num_timesteps=16000, episode_reward=417.80 +/- 58.45
# Episode length: 417.80 +/- 58.45
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       |