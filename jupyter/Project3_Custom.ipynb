# %% [markdown]
# # Custom Environment
# ## 1. Import

# %%
import gymnasium as gym
from gymnasium import Env
from gymnasium.spaces import Discrete, Box, Dict, Tuple, MultiBinary, MultiDiscrete

import os
import numpy as np
import random

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# ## 2. Types of Spaces

# %%
Discrete(3).sample() # Value between 0 till 3
# Out:
# 2

# %%
Box(0,1,shape=(3,3)).sample() # Value low=0, high=1, shape is output shape, in this case array of arrays (matrix)
# Out:
# array([[0.74903476, 0.7298928 , 0.9465985 ],
#        [0.7472668 , 0.8261999 , 0.18240553],
#        [0.9845458 , 0.7449783 , 0.41522068]], dtype=float32)

# %%
Tuple((Discrete(3),Box(0,1,shape=(3,)))).sample() # Tuple combines different spaces
# Out:
# (1, array([0.37930974, 0.2735864 , 0.77152306], dtype=float32))

# %%
Dict({'height':Discrete(2), 'speed':Box(0,100,shape=(1,))}).sample() # same as Tuple() but using a dictionary
# Out:
# OrderedDict([('height', 0), ('speed', array([87.94416], dtype=float32))])

# %%
MultiBinary(4).sample() # One hot encoding of multiple discrete values
# Out:
# array([0, 1, 0, 1], dtype=int8)

# %%
MultiDiscrete([5,2,2]).sample() # Multiple discrete values ranges
# Out:
# array([0, 0, 1])

# %% [markdown]
# ## 3. Building an Environment

# %%
class ShowerEnv(Env):
    def __init__(self,simple=True):
        self.action_space = Discrete(3)
        self.observation_space = Box(low=0,high=100,shape=(1,))
        self.state = 38 + random.randint(-3,3)
        self.shower_length = 60
        self.info = {}
        self.simple = simple
        
    def step(self,action):
        # Apply action (change in temperature)
        self.state += action -1

        # Decrease episode lenght remaining (shower time)
        self.shower_length -= 1

        # Define reward function (immediate reward)
        if self.state >= 37 and self.state <= 39:
            if self.simple:
                reward = 1
            else:
                reward = 10
        else:
            if self.simple:
                reward = -1
            else:
                reward = -1 * 0.1*(60-self.shower_length)

        if self.shower_length <=0:
            truncated = True
            terminated = True
        else:
            truncated = False
            terminated = False

        return self.state,reward,terminated,truncated,self.info
        
    def render(self):
        pass
        
    def reset(self, seed=None):
        self.state = np.array([38 + random.randint(-3, 3)]).astype(float)
        self.shower_length = 60
        return self.state, {}

# %%
env_simple = ShowerEnv(simple=True)
env_advanced = ShowerEnv(simple=False)

# %% [markdown]
# ## 4. Test Environment

# %%
episodes =5
for episode in range(1,episodes+1):
    obs = env_simple.reset()
    terminated = False
    score = 0
    
    while not terminated:
        env_simple.render()
        action = env_simple.action_space.sample()
        obs, reward, terminated,truncated, info = env_simple.step(action) 
        score += reward
    print('Episode:{} Score:{}'.format(episode,score))
env.close()
# Out:
# Episode:1 Score:-46
# Episode:2 Score:-26
# Episode:3 Score:-44
# Episode:4 Score:22
# Episode:5 Score:-24

# %% [markdown]
# ## 5. Train Model

# %%
log_path = os.path.join('Training','Logs')
model_simple = PPO('MlpPolicy',env_simple,verbose=1,tensorboard_log=log_path)
model_advanced = PPO('MlpPolicy',env_advanced,verbose=1,tensorboard_log=log_path)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
# model_simple.learn(total_timesteps=80000)
model_advanced.learn(total_timesteps=80000)
# Out:
# Logging to Training/Logs/PPO_22
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 108      |
# | time/              |          |
# |    fps             | 850      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -14.6        |
# | time/                   |              |
# |    fps                  | 706          |
# |    iterations           | 2            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0072826417 |
# |    clip_fraction        | 0.0305       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 3.2e-05      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 968          |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.000767    |
# |    value_loss           | 2.03e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 22.8         |
# | time/                   |              |
# |    fps                  | 682          |
# |    iterations           | 3            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0069563757 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -4.49e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 974          |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00166     |
# |    value_loss           | 2.52e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -21.2       |
# | time/                   |             |
# |    fps                  | 658         |
# |    iterations           | 4           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010456804 |
# |    clip_fraction        | 0.0451      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.00293     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 862         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00319    |
# |    value_loss           | 1.71e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 54.1        |
# | time/                   |             |
# |    fps                  | 661         |
# |    iterations           | 5           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.013535544 |
# |    clip_fraction        | 0.036       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 6.32e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.02e+03    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | 0.000668    |
# |    value_loss           | 2.12e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -158        |
# | time/                   |             |
# |    fps                  | 664         |
# |    iterations           | 6           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.012574536 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 3.83e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 900         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0114     |
# |    value_loss           | 2.5e+03     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 2.1          |
# | time/                   |              |
# |    fps                  | 669          |
# |    iterations           | 7            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0150299575 |
# |    clip_fraction        | 0.0525       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | -0.00177     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.27e+03     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00744     |
# |    value_loss           | 2.78e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 114         |
# | time/                   |             |
# |    fps                  | 663         |
# |    iterations           | 8           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.018810615 |
# |    clip_fraction        | 0.047       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.991      |
# |    explained_variance   | -0.000654   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.39e+03    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00493    |
# |    value_loss           | 2.86e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 284          |
# | time/                   |              |
# |    fps                  | 659          |
# |    iterations           | 9            |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0044008167 |
# |    clip_fraction        | 0.0374       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.938       |
# |    explained_variance   | 0.000251     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.22e+03     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00104     |
# |    value_loss           | 3.68e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -35.7       |
# | time/                   |             |
# |    fps                  | 659         |
# |    iterations           | 10          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.005809472 |
# |    clip_fraction        | 0.0319      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.951      |
# |    explained_variance   | -0.000503   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.35e+03    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00194    |
# |    value_loss           | 3.87e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 225         |
# | time/                   |             |
# |    fps                  | 653         |
# |    iterations           | 11          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.006575077 |
# |    clip_fraction        | 0.0538      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.936      |
# |    explained_variance   | 2.79e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.24e+03    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | 0.00122     |
# |    value_loss           | 2.59e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 57.6         |
# | time/                   |              |
# |    fps                  | 651          |
# |    iterations           | 12           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0079013035 |
# |    clip_fraction        | 0.0525       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.958       |
# |    explained_variance   | -0.000623    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.41e+03     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00554     |
# |    value_loss           | 2.08e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 74.7         |
# | time/                   |              |
# |    fps                  | 650          |
# |    iterations           | 13           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0032258448 |
# |    clip_fraction        | 0.026        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.938       |
# |    explained_variance   | 0.000314     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 802          |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00055     |
# |    value_loss           | 2.36e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 194          |
# | time/                   |              |
# |    fps                  | 653          |
# |    iterations           | 14           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0021971716 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.927       |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.39e+03     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.000614    |
# |    value_loss           | 3.5e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 234          |
# | time/                   |              |
# |    fps                  | 656          |
# |    iterations           | 15           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0049975533 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.902       |
# |    explained_variance   | -0.0012      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.16e+03     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00106     |
# |    value_loss           | 3.13e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 103          |
# | time/                   |              |
# |    fps                  | 658          |
# |    iterations           | 16           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0021208338 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.869       |
# |    explained_variance   | 0.00123      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.93e+03     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | 0.000246     |
# |    value_loss           | 3.66e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -12.4       |
# | time/                   |             |
# |    fps                  | 660         |
# |    iterations           | 17          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.004614966 |
# |    clip_fraction        | 0.0261      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.816      |
# |    explained_variance   | 0.00438     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.88e+03    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00183    |
# |    value_loss           | 3.39e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 33.6         |
# | time/                   |              |
# |    fps                  | 661          |
# |    iterations           | 18           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0039854925 |
# |    clip_fraction        | 0.0229       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.804       |
# |    explained_variance   | -0.0064      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.73e+03     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00138     |
# |    value_loss           | 3.85e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 79           |
# | time/                   |              |
# |    fps                  | 662          |
# |    iterations           | 19           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0052560763 |
# |    clip_fraction        | 0.0352       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.768       |
# |    explained_variance   | 0.000575     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.78e+03     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00245     |
# |    value_loss           | 3.9e+03      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -183        |
# | time/                   |             |
# |    fps                  | 663         |
# |    iterations           | 20          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.004048848 |
# |    clip_fraction        | 0.0609      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.778      |
# |    explained_variance   | -0.00559    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.52e+03    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.000109   |
# |    value_loss           | 3.9e+03     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -109         |
# | time/                   |              |
# |    fps                  | 664          |
# |    iterations           | 21           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0030689577 |
# |    clip_fraction        | 0.0194       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.804       |
# |    explained_variance   | 6.51e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.53e+03     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00175     |
# |    value_loss           | 3.35e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -68          |
# | time/                   |              |
# |    fps                  | 663          |
# |    iterations           | 22           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0023407484 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.782       |
# |    explained_variance   | 0.0172       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.67e+03     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00158     |
# |    value_loss           | 2.5e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -158         |
# | time/                   |              |
# |    fps                  | 662          |
# |    iterations           | 23           |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0021640277 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.751       |
# |    explained_variance   | 0.0114       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.84e+03     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00166     |
# |    value_loss           | 3.74e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -58.2        |
# | time/                   |              |
# |    fps                  | 661          |
# |    iterations           | 24           |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0035910346 |
# |    clip_fraction        | 0.0225       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.704       |
# |    explained_variance   | 0.00506      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.86e+03     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00192     |
# |    value_loss           | 4.3e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 49.6         |
# | time/                   |              |
# |    fps                  | 660          |
# |    iterations           | 25           |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0012370759 |
# |    clip_fraction        | 0.0137       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.651       |
# |    explained_variance   | 0.000651     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.46e+03     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | 0.000273     |
# |    value_loss           | 4.59e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 191         |
# | time/                   |             |
# |    fps                  | 660         |
# |    iterations           | 26          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.017410705 |
# |    clip_fraction        | 0.0489      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.584      |
# |    explained_variance   | -0.000237   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.21e+03    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00255    |
# |    value_loss           | 4.83e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 218          |
# | time/                   |              |
# |    fps                  | 660          |
# |    iterations           | 27           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0021593722 |
# |    clip_fraction        | 0.0487       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.484       |
# |    explained_variance   | 2.44e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.12e+03     |
# |    n_updates            | 260          |
# |    policy_gradient_loss | 8.37e-05     |
# |    value_loss           | 4.53e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -87.4        |
# | time/                   |              |
# |    fps                  | 659          |
# |    iterations           | 28           |
# |    time_elapsed         | 86           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0002349785 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.468       |
# |    explained_variance   | 0.00243      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.03e+03     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.000303    |
# |    value_loss           | 5.65e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 203          |
# | time/                   |              |
# |    fps                  | 659          |
# |    iterations           | 29           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 7.336863e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.469       |
# |    explained_variance   | 0.0141       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.19e+03     |
# |    n_updates            | 280          |
# |    policy_gradient_loss | 3.43e-05     |
# |    value_loss           | 4.46e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -183          |
# | time/                   |               |
# |    fps                  | 658           |
# |    iterations           | 30            |
# |    time_elapsed         | 93            |
# |    total_timesteps      | 61440         |
# | train/                  |               |
# |    approx_kl            | 5.7062483e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.47         |
# |    explained_variance   | 0.0376        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.31e+03      |
# |    n_updates            | 290           |
# |    policy_gradient_loss | -0.000314     |
# |    value_loss           | 5.88e+03      |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 60             |
# |    ep_rew_mean          | 144            |
# | time/                   |                |
# |    fps                  | 658            |
# |    iterations           | 31             |
# |    time_elapsed         | 96             |
# |    total_timesteps      | 63488          |
# | train/                  |                |
# |    approx_kl            | 0.000118238764 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -0.477         |
# |    explained_variance   | 0.037          |
# |    learning_rate        | 0.0003         |
# |    loss                 | 2.11e+03       |
# |    n_updates            | 300            |
# |    policy_gradient_loss | 0.000141       |
# |    value_loss           | 4.95e+03       |
# --------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 95.2         |
# | time/                   |              |
# |    fps                  | 657          |
# |    iterations           | 32           |
# |    time_elapsed         | 99           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 3.747124e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.474       |
# |    explained_variance   | 0.0603       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.96e+03     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.000197    |
# |    value_loss           | 4.27e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | 152           |
# | time/                   |               |
# |    fps                  | 657           |
# |    iterations           | 33            |
# |    time_elapsed         | 102           |
# |    total_timesteps      | 67584         |
# | train/                  |               |
# |    approx_kl            | 5.0911505e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.47         |
# |    explained_variance   | 0.105         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.82e+03      |
# |    n_updates            | 320           |
# |    policy_gradient_loss | -0.000227     |
# |    value_loss           | 5.96e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | 225           |
# | time/                   |               |
# |    fps                  | 656           |
# |    iterations           | 34            |
# |    time_elapsed         | 106           |
# |    total_timesteps      | 69632         |
# | train/                  |               |
# |    approx_kl            | 2.9679795e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.466        |
# |    explained_variance   | 0.0937        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.82e+03      |
# |    n_updates            | 330           |
# |    policy_gradient_loss | -1.13e-05     |
# |    value_loss           | 6.14e+03      |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 60             |
# |    ep_rew_mean          | 177            |
# | time/                   |                |
# |    fps                  | 655            |
# |    iterations           | 35             |
# |    time_elapsed         | 109            |
# |    total_timesteps      | 71680          |
# | train/                  |                |
# |    approx_kl            | 0.000113235874 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -0.459         |
# |    explained_variance   | 0.0815         |
# |    learning_rate        | 0.0003         |
# |    loss                 | 3.29e+03       |
# |    n_updates            | 340            |
# |    policy_gradient_loss | -0.000281      |
# |    value_loss           | 5.74e+03       |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -117          |
# | time/                   |               |
# |    fps                  | 655           |
# |    iterations           | 36            |
# |    time_elapsed         | 112           |
# |    total_timesteps      | 73728         |
# | train/                  |               |
# |    approx_kl            | 2.9474817e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.453        |
# |    explained_variance   | 0.0957        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.11e+03      |
# |    n_updates            | 350           |
# |    policy_gradient_loss | -3.14e-06     |
# |    value_loss           | 4.67e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | 161           |
# | time/                   |               |
# |    fps                  | 655           |
# |    iterations           | 37            |
# |    time_elapsed         | 115           |
# |    total_timesteps      | 75776         |
# | train/                  |               |
# |    approx_kl            | 0.00011758169 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.442        |
# |    explained_variance   | 0.107         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.63e+03      |
# |    n_updates            | 360           |
# |    policy_gradient_loss | -0.000189     |
# |    value_loss           | 5.01e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -2.09         |
# | time/                   |               |
# |    fps                  | 655           |
# |    iterations           | 38            |
# |    time_elapsed         | 118           |
# |    total_timesteps      | 77824         |
# | train/                  |               |
# |    approx_kl            | 8.8977366e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.433        |
# |    explained_variance   | 0.0974        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.21e+03      |
# |    n_updates            | 370           |
# |    policy_gradient_loss | -0.000272     |
# |    value_loss           | 5.38e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -34.5         |
# | time/                   |               |
# |    fps                  | 655           |
# |    iterations           | 39            |
# |    time_elapsed         | 121           |
# |    total_timesteps      | 79872         |
# | train/                  |               |
# |    approx_kl            | 0.00014272882 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.425        |
# |    explained_variance   | 0.162         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.77e+03      |
# |    n_updates            | 380           |
# |    policy_gradient_loss | -0.000509     |
# |    value_loss           | 6.03e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | 367           |
# | time/                   |               |
# |    fps                  | 652           |
# |    iterations           | 40            |
# |    time_elapsed         | 125           |
# |    total_timesteps      | 81920         |
# | train/                  |               |
# |    approx_kl            | 7.0775655e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.418        |
# |    explained_variance   | 0.0197        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.42e+03      |
# |    n_updates            | 390           |
# |    policy_gradient_loss | -0.000125     |
# |    value_loss           | 5.46e+03      |
# -------------------------------------------

# %% [markdown]
# ## 6. Save Model

# %%
shower_path_simple = os.path.join('Training','Saved_Models','Shower_Model_PPO_simpleReward')
shower_path_advanced = os.path.join('Training','Saved_Models','Shower_Model_PPO')
model_advanced.save(shower_path_advanced)

# %%
try:
    del model_simple
except:
    print("model simple does not exist")
try:
    del model_advanced
except:
    print("model advanced does not exist")
    
model_simple = PPO.load(shower_path_simple,env_simple)
model_advanced = PPO.load(shower_path_advanced,env_advanced)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
avg_reward,variance = evaluate_policy(model_simple,env_simple,n_eval_episodes=10,render=False)
print('simple model: avg_reward:{}, variance:{}'.format(avg_reward,variance))
avg_reward,variance = evaluate_policy(model_advanced,env_advanced,n_eval_episodes=10,render=False)
print('advanced model: avg_reward:{}, variance:{}'.format(avg_reward,variance))
# Out:
# simple model: avg_reward:59.4, variance:0.9165151389911681
# advanced model: avg_reward:286.7999999910593, variance:383.5900937307958

# %% [markdown]
# Much higer variance in
